# %% [markdown]
# NOME: Hercules André

# %% [markdown]
# Atividade 02 - Exercicio 12:
#
# Start Point: [3.0, 4.0, 5.0]

# %% [markdown]
# IMPORTAR A BIBLIOTECA

# %%
using LinearAlgebra

# %% [markdown]
# FUNÇÃO

# %%
function f(x)
    x1, x2, x3 = x
    return log(exp(x1) + exp(x2)) + 1/(x1 + x2) + (x3 - 2)^2
end
# Out:
# f (generic function with 1 method)

# %% [markdown]
# GRADIENTE

# %%
function grad_f(x)
    x1, x2, x3 = x
    
    denom = exp(x1) + exp(x2)
    
    df_dx1 = exp(x1)/denom - 1/(x1 + x2)^2
    df_dx2 = exp(x2)/denom - 1/(x1 + x2)^2
    df_dx3 = 2*(x3 - 2)
    
    return [df_dx1, df_dx2, df_dx3]
end
# Out:
# grad_f (generic function with 1 method)

# %% [markdown]
# PARAMETROS

# %%
alpha = 0.4
beta = 0.5
eps = 1e-5
# Out:
# 1.0e-5

# %% [markdown]
# BACKTRANKING

# %%
function backtracking(f, grad_f, x, d; alpha=0.4, beta=0.5)
    
    t = 1.0
    
    while f(x + t*d) > f(x) + alpha * t * dot(grad_f(x), d)
        t = beta * t
    end
    
    return t
end
# Out:
# backtracking (generic function with 1 method)

# %% [markdown]
# GRADIENT DESCENT

# %%
function gradient_descent_bt(f, grad_f, x0; alpha=0.4, beta=0.5, eps=1e-5, max_iter=1000)
    
    x = x0
    history = [x0]
    
    for k in 1:max_iter
        
        g = grad_f(x)
        
        println("Iteração ", k)
        println("x = ", x)
        println("||grad|| = ", norm(g))
        println("------------------------")
        
        if norm(g) < eps
            println("Convergiu!")
            break
        end
        
        d = -g
        
        t = backtracking(f, grad_f, x, d, alpha=alpha, beta=beta)
        
        x = x + t*d
        
        push!(history, x)
    end
    
    return x, history
end
# Out:
# gradient_descent_bt (generic function with 1 method)

# %% [markdown]
# COM PONTO INICIAL

# %%
x0 = [3.0, 4.0, 5.0]

x_min, history = gradient_descent_bt(f, grad_f, x0)

println("Mínimo encontrado: ", x_min)
# Out:
# Iteração 1
# x = [3.0, 4.0, 5.0]
# ||grad|| = 6.047048271118906
# ------------------------
# Iteração 2
# x = [2.8757333709476556, 3.644674792317651, 2.0]
# ||grad|| = 0.7219811886796266
# ------------------------
# Iteração 3
# x = [2.5825459388160574, 2.9849036452921642, 2.0]
# ||grad|| = 0.6762107079636196
# ------------------------
# Iteração 4
# x = [2.2140616435147824, 2.4179113652027593, 2.0]
# ||grad|| = 0.6452020826178302
# ------------------------
# Iteração 5
# x = [1.8114571309114087, 1.913733486031345, 2.0]
# ||grad|| = 0.6062739354269087
# ------------------------
# Iteração 6
# x = [1.409065404729191, 1.4602481130829703, 2.0]
# ||grad|| = 0.535637789656504
# ------------------------
# Iteração 7
# x = [1.0433212857542644, 1.0689182252091203, 2.0]
# ||grad|| = 0.39023404788963467
# ------------------------
# Iteração 8
# x = [0.7738572336601073, 0.7866564021417295, 2.0]
# ||grad|| = 0.12645028635823563
# ------------------------
# Iteração 9
# ...
