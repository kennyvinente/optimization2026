# %% [markdown]
# NOME:  Hercules André

# %% [markdown]
# Atividade 02 - Exercicio 06 :
#
# Implement the same methods for the function f(x) = x[1]^2 + x[2]^2
#
# Ponto inicial: x = [-2.0,2.0]

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Importar Biblioteca

# %%
using LinearAlgebra

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Função

# %%
f(x) = x[1]^2 + x[2]^2
# Out:
# f (generic function with 1 method)

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Gradiente

# %%
grad_f(x) = [2*x[1], 2*x[2]]
# Out:
# grad_f (generic function with 1 method)

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Parâmetros

# %%
x = [-2.0, 2.0]
α = 0.1
tol = 1e-6
max_iter = 100
# Out:
# 100

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Resultado do Gradient Descent

# %%
println("Mínimo aproximado (Gradient Descent): ", x)
# Out:
# Mínimo aproximado (Gradient Descent): [-2.0, 2.0]

# %% [markdown]
# MÉTODO DE NEWTON

# %% [markdown]
# Hessiana

# %%
hessian_f(x) = [2.0 0.0; 0.0 2.0]
# Out:
# hessian_f (generic function with 1 method)

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Inicialização

# %%
x = [-2.0, 2.0]
tol = 1e-6
max_iter = 10
# Out:
# 10

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Resultado Método de Newton

# %%
println("Mínimo aproximado (Newton): ", x)
# Out:
# Mínimo aproximado (Newton): [-2.0, 2.0]
